# %%
import numpy as np
import pandas as pd

# %%
x = pd.read_csv("wine reviews.csv")

# %%
x["country"];

# %%
print(x)
# Out:
#         Unnamed: 0      country  \
# 0                0        Italy
# 1                1     Portugal
# 2                2           US
# 3                3           US
# 4                4           US
# 5                5        Spain
# 6                6        Italy
# 7                7       France
# 8                8      Germany
# 9                9       France
# 10              10           US
# 11              11       France
# 12              12           US
# 13              13        Italy
# 14              14           US
# 15              15      Germany
# 16              16    Argentina
# 17              17    Argentina
# 18              18        Spain
# 19              19           US
# 20              20           US
# 21              21           US
# 22              22        Italy
# 23              23           US
# 24              24        Italy
# 25              25           US
# 26              26        Italy
# 27              27        Italy
# ...

# %%
x[["country","description","designation"]]
# Out:
#             country                                        description  \
# 0             Italy  Aromas include tropical fruit, broom, brimston...
# 1          Portugal  This is ripe and fruity, a wine that is smooth...
# 2                US  Tart and snappy, the flavors of lime flesh and...
# 3                US  Pineapple rind, lemon pith and orange blossom ...
# 4                US  Much like the regular bottling from 2012, this...
# 5             Spain  Blackberry and raspberry aromas show a typical...
# 6             Italy  Here's a bright, informal red that opens with ...
# 7            France  This dry and restrained wine offers spice in p...
# 8           Germany  Savory dried thyme notes accent sunnier flavor...
# 9            France  This has great depth of flavor with its fresh ...
# 10               US  Soft, supple plum envelopes an oaky structure ...
# 11           France  This is a dry wine, very spicy, with a tight, ...
# ...

# %%
x.loc[0]
# Out:
# Unnamed: 0                                                               0
# country                                                              Italy
# description              Aromas include tropical fruit, broom, brimston...
# designation                                                   Vulkà Bianco
# points                                                                  87
# price                                                                  NaN
# province                                                 Sicily & Sardinia
# region_1                                                              Etna
# region_2                                                               NaN
# taster_name                                                  Kerin O’Keefe
# taster_twitter_handle                                         @kerinokeefe
# title                                    Nicosia 2013 Vulkà Bianco  (Etna)
# ...

# %%
x.iloc[0]
# Out:
# Unnamed: 0                                                               0
# country                                                              Italy
# description              Aromas include tropical fruit, broom, brimston...
# designation                                                   Vulkà Bianco
# points                                                                  87
# price                                                                  NaN
# province                                                 Sicily & Sardinia
# region_1                                                              Etna
# region_2                                                               NaN
# taster_name                                                  Kerin O’Keefe
# taster_twitter_handle                                         @kerinokeefe
# title                                    Nicosia 2013 Vulkà Bianco  (Etna)
# ...

# %%
x.loc[0:10]
# Out:
#     Unnamed: 0   country                                        description  \
# 0            0     Italy  Aromas include tropical fruit, broom, brimston...
# 1            1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2            2        US  Tart and snappy, the flavors of lime flesh and...
# 3            3        US  Pineapple rind, lemon pith and orange blossom ...
# 4            4        US  Much like the regular bottling from 2012, this...
# 5            5     Spain  Blackberry and raspberry aromas show a typical...
# 6            6     Italy  Here's a bright, informal red that opens with ...
# 7            7    France  This dry and restrained wine offers spice in p...
# 8            8   Germany  Savory dried thyme notes accent sunnier flavor...
# 9            9    France  This has great depth of flavor with its fresh ...
# 10          10        US  Soft, supple plum envelopes an oaky structure ...
#
# ...

# %%
x.iloc[0:10]
# Out:
#    Unnamed: 0   country                                        description  \
# 0           0     Italy  Aromas include tropical fruit, broom, brimston...
# 1           1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2           2        US  Tart and snappy, the flavors of lime flesh and...
# 3           3        US  Pineapple rind, lemon pith and orange blossom ...
# 4           4        US  Much like the regular bottling from 2012, this...
# 5           5     Spain  Blackberry and raspberry aromas show a typical...
# 6           6     Italy  Here's a bright, informal red that opens with ...
# 7           7    France  This dry and restrained wine offers spice in p...
# 8           8   Germany  Savory dried thyme notes accent sunnier flavor...
# 9           9    France  This has great depth of flavor with its fresh ...
#
#                           designation  points  price           province  \
# ...

# %%
x.iloc[[1,3,5]]
# Out:
#    Unnamed: 0   country                                        description  \
# 1           1  Portugal  This is ripe and fruity, a wine that is smooth...
# 3           3        US  Pineapple rind, lemon pith and orange blossom ...
# 5           5     Spain  Blackberry and raspberry aromas show a typical...
#
#             designation  points  price        province             region_1  \
# 1              Avidagos      87   15.0           Douro                  NaN
# 3  Reserve Late Harvest      87   13.0        Michigan  Lake Michigan Shore
# 5          Ars In Vitro      87   15.0  Northern Spain              Navarra
#
#   region_2         taster_name taster_twitter_handle  \
# 1      NaN          Roger Voss            @vossroger
# 3      NaN  Alexander Peartree                   NaN
# 5      NaN   Michael Schachner           @wineschach
#
#                                                title             variety  \
# ...

# %%
x.loc[[1,3,5]]
# Out:
#    Unnamed: 0   country                                        description  \
# 1           1  Portugal  This is ripe and fruity, a wine that is smooth...
# 3           3        US  Pineapple rind, lemon pith and orange blossom ...
# 5           5     Spain  Blackberry and raspberry aromas show a typical...
#
#             designation  points  price        province             region_1  \
# 1              Avidagos      87   15.0           Douro                  NaN
# 3  Reserve Late Harvest      87   13.0        Michigan  Lake Michigan Shore
# 5          Ars In Vitro      87   15.0  Northern Spain              Navarra
#
#   region_2         taster_name taster_twitter_handle  \
# 1      NaN          Roger Voss            @vossroger
# 3      NaN  Alexander Peartree                   NaN
# 5      NaN   Michael Schachner           @wineschach
#
#                                                title             variety  \
# ...

# %%
x.loc[0:10,["country","title"]]
# Out:
#      country                                              title
# 0      Italy                  Nicosia 2013 Vulkà Bianco  (Etna)
# 1   Portugal      Quinta dos Avidagos 2011 Avidagos Red (Douro)
# 2         US      Rainstorm 2013 Pinot Gris (Willamette Valley)
# 3         US  St. Julian 2013 Reserve Late Harvest Riesling ...
# 4         US  Sweet Cheeks 2012 Vintner's Reserve Wild Child...
# 5      Spain  Tandem 2011 Ars In Vitro Tempranillo-Merlot (N...
# 6      Italy   Terre di Giurfo 2013 Belsito Frappato (Vittoria)
# 7     France              Trimbach 2012 Gewurztraminer (Alsace)
# 8    Germany  Heinz Eifel 2013 Shine Gewürztraminer (Rheinhe...
# 9     France  Jean-Baptiste Adam 2012 Les Natures Pinot Gris...
# 10        US  Kirkland Signature 2011 Mountain Cuvée Caberne...

# %%
x.loc[x.country=="Italy", ["country","price","winery"]] #displays wines reviews in Italy for the prices only
# Out:
#        country  price                           winery
# 0        Italy    NaN                          Nicosia
# 6        Italy   16.0                  Terre di Giurfo
# 13       Italy    NaN              Masseria Setteporte
# 22       Italy   19.0               Baglio di Pianetto
# 24       Italy   35.0                        Canicattì
# 26       Italy   13.0                         Stemmari
# 27       Italy   10.0                         Stemmari
# 28       Italy   17.0                  Terre di Giurfo
# 31       Italy    NaN               Duca di Salaparuta
# 32       Italy    NaN               Duca di Salaparuta
# 37       Italy   21.0              Feudi del Pisciotto
# 38       Italy   11.0             Feudi di San Marzano
# 39       Italy   12.0             Feudo di Santa Tresa
# 40       Italy   17.0                    Feudo Montoni
# 46       Italy   13.0                 Tasca d'Almerita
# 50       Italy    NaN  Viticultori Associati Canicatti
# ...

# %%
x.loc[(x.price>70) & x.country.isin(["South Africa", "US"]),["title"]]
# Out:
#                                                     title
# 60      Okapi 2013 Estate Cabernet Sauvignon (Napa Val...
# 73      Hindsight 2013 Bella Vetta Vineyard Cabernet S...
# 75      Mulvane Wine Co. 2013 The Cypher Red (Napa Val...
# 99      Soquel Vineyards 2013 Intreccio Library Select...
# 111     Piña 2013 Wolff Vineyard Cabernet Sauvignon (Y...
# 134     Clark-Clauden 2007 Cabernet Sauvignon (Napa Va...
# 144     Terra Valentine 2013 K Block Cabernet Sauvigno...
# 168     Duckhorn 2012 Rector Creek Vineyard Merlot (Na...
# 236     Meeker 2004 Kiss Ridge Vineyard Cabernet Sauvi...
# 289     Parallel 2010 Fortune Teller Cabernet Sauvigno...
# 362     J. Davies 2012 Jamie Cabernet Sauvignon (Diamo...
# 370     Sebastiani 1991 Cherryblock Vineyard Cabernet ...
# 475     Bell 2009 Clone 6 Cabernet Sauvignon (Rutherford)
# 476     Castello di Amorosa 2009 La Castellana Red (Na...
# 513     Conn Creek 2013 El Adobo Ranch Vineyard Cabern...
# ...

# %%
x.loc[(x.price>100) & x.country.isin(["Australia"]),["title"]]
# Out:
#                                                     title
# 345     Chambers Rosewood Vineyards NV Rare Muscat (Ru...
# 346     Chambers Rosewood Vineyards NV Rare Muscadelle...
# 349        Torbreck 2012 RunRig Shiraz-Viognier (Barossa)
# 360     Torbreck 2012 Descendant Shiraz-Viognier (Baro...
# 636      Torbreck 2010 The Factor Shiraz (Barossa Valley)
# 2517    Torbreck 2010 RunRig Shiraz-Viognier (Barossa ...
# 3080    Torbreck 2007 Descendant Shiraz-Viognier (Baro...
# 9251    Kay Brothers 2014 Amery Vineyard Block 6 Shira...
# 15209   Cullen 2013 Kevin John Chardonnay (Margaret Ri...
# 15547   Chambers Rosewood Vineyards NV Grand Muscadell...
# 17054   Torbreck 2010 Descendant Shiraz-Viognier (Baro...
# 18852          Mount Mary 2010 Quintet Red (Yarra Valley)
# 19378          Mount Mary 2010 Quintet Red (Yarra Valley)
# 21451          Yalumba 2009 The Octavius Shiraz (Barossa)
# 21463         Cloudburst 2013 Chardonnay (Margaret River)
# ...

# %%
countries= x.country.unique()
countries
# Out:
# array(['Italy', 'Portugal', 'US', 'Spain', 'France', 'Germany',
#        'Argentina', 'Chile', 'Australia', 'Austria', 'South Africa',
#        'New Zealand', 'Israel', 'Hungary', 'Greece', 'Romania', 'Mexico',
#        'Canada', nan, 'Turkey', 'Czech Republic', 'Slovenia',
#        'Luxembourg', 'Croatia', 'Georgia', 'Uruguay', 'England',
#        'Lebanon', 'Serbia', 'Brazil', 'Moldova', 'Morocco', 'Peru',
#        'India', 'Bulgaria', 'Cyprus', 'Armenia', 'Switzerland',
#        'Bosnia and Herzegovina', 'Ukraine', 'Slovakia', 'Macedonia',
#        'China', 'Egypt'], dtype=object)

# %%
count= x.country.value_counts()
count
# Out:
# US                        54504
# France                    22093
# Italy                     19540
# Spain                      6645
# Portugal                   5691
# Chile                      4472
# Argentina                  3800
# Austria                    3345
# Australia                  2329
# Germany                    2165
# New Zealand                1419
# South Africa               1401
# Israel                      505
# Greece                      466
# Canada                      257
# Hungary                     146
# Bulgaria                    141
# Romania                     120
# Uruguay                     109
# Turkey                       90
# Slovenia                     87
# Georgia                      86
# England                      74
# Croatia                      73
# Mexico                       70
# Moldova                      59
# Brazil                       52
# Lebanon                      35
# Morocco                      28
# ...

# %%
ratio= x.points/x.price
bargain= ratio.idxmax()
bargain
# Out:
# 64590

# %%
x.loc[bargain,["title","country"]]
# Out:
# title      Bandit NV Merlot (California)
# country                               US
# Name: 64590, dtype: object

# %%
tasters = x.taster_name.unique()
tasters
# Out:
# array(['Kerin O’Keefe', 'Roger Voss', 'Paul Gregutt',
#        'Alexander Peartree', 'Michael Schachner', 'Anna Lee C. Iijima',
#        'Virginie Boone', 'Matt Kettmann', nan, 'Sean P. Sullivan',
#        'Jim Gordon', 'Joe Czerwinski', 'Anne Krebiehl\xa0MW',
#        'Lauren Buzzeo', 'Mike DeSimone', 'Jeff Jenssen',
#        'Susan Kostrzewa', 'Carrie Dykes', 'Fiona Adams',
#        'Christina Pickard'], dtype=object)

# %%
len(tasters)  #how many tasters were asked to sample
# Out:
# 20

# %%
#for each taster, how many wine samples did they review
count_tasters= x.taster_name.value_counts()
count_tasters
# Out:
# Roger Voss            25514
# Michael Schachner     15134
# Kerin O’Keefe         10776
# Virginie Boone         9537
# Paul Gregutt           9532
# Matt Kettmann          6332
# Joe Czerwinski         5147
# Sean P. Sullivan       4966
# Anna Lee C. Iijima     4415
# Jim Gordon             4177
# Anne Krebiehl MW       3685
# Lauren Buzzeo          1835
# Susan Kostrzewa        1085
# Mike DeSimone           514
# Jeff Jenssen            491
# Alexander Peartree      415
# Carrie Dykes            139
# Fiona Adams              27
# Christina Pickard         6
# Name: taster_name, dtype: int64

# %%
#combine the columns country and region_1 to give you the country and region separated by a hyphen e.g Italy-Etna
combi = x.country + "-" + x.region_1
combi
# Out:
# 0                          Italy-Etna
# 1                                 NaN
# 2                US-Willamette Valley
# 3              US-Lake Michigan Shore
# 4                US-Willamette Valley
# 5                       Spain-Navarra
# 6                      Italy-Vittoria
# 7                       France-Alsace
# 8                                 NaN
# 9                       France-Alsace
# 10                     US-Napa Valley
# 11                      France-Alsace
# 12                US-Alexander Valley
# 13                         Italy-Etna
# 14                   US-Central Coast
# 15                                NaN
# 16                 Argentina-Cafayate
# 17                  Argentina-Mendoza
# 18             Spain-Ribera del Duero
# 19                        US-Virginia
# 20                        US-Virginia
# 21                          US-Oregon
# 22                      Italy-Sicilia
# 23                     US-Paso Robles
# 24                      Italy-Sicilia
# ...

# %%
x.description.map(lambda desc: "tropical" in desc).sum()
# Out:
# 3607

# %%
x.description.map(lambda desc: "tropical" in desc)
# Out:
# 0          True
# 1         False
# 2         False
# 3         False
# 4         False
# 5         False
# 6         False
# 7         False
# 8         False
# 9         False
# 10        False
# 11        False
# 12        False
# 13        False
# 14        False
# 15        False
# 16        False
# 17        False
# 18        False
# 19        False
# 20        False
# 21        False
# 22        False
# 23        False
# 24        False
# 25        False
# 26        False
# 27        False
# 28        False
# 29        False
#           ...
# 129941    False
# 129942    False
# 129943    False
# 129944    False
# 129945    False
# 129946    False
# 129947    False
# 129948    False
# 129949    False
# 129950    False
# 129951    False
# 129952    False
# 129953    False
# 129954    False
# 129955    False
# 129956    False
# 129957    False
# 129958    False
# 129959    False
# 129960    False
# 129961    False
# 129962    False
# 129963    False
# 129964    False
# ...

# %%
x.description.map(lambda fi: "wine" in fi).sum()
# Out:
# 67626

# %%
x.groupby("country").country.count()  #replica of value_counts
# Out:
# country
# Argentina                  3800
# Armenia                       2
# Australia                  2329
# Austria                    3345
# Bosnia and Herzegovina        2
# Brazil                       52
# Bulgaria                    141
# Canada                      257
# Chile                      4472
# China                         1
# Croatia                      73
# Cyprus                       11
# Czech Republic               12
# Egypt                         1
# England                      74
# France                    22093
# Georgia                      86
# Germany                    2165
# Greece                      466
# Hungary                     146
# India                         9
# Israel                      505
# Italy                     19540
# Lebanon                      35
# Luxembourg                    6
# Macedonia                    12
# Mexico                       70
# Moldova                      59
# Morocco                      28
# ...

# %%
x.groupby("points").points.count()
# Out:
# points
# 80       397
# 81       692
# 82      1836
# 83      3025
# 84      6480
# 85      9530
# 86     12600
# 87     16933
# 88     17207
# 89     12226
# 90     15410
# 91     11359
# 92      9613
# 93      6489
# 94      3758
# 95      1535
# 96       523
# 97       229
# 98        77
# 99        33
# 100       19
# Name: points, dtype: int64

# %%
x.groupby("taster_name").points.mean()
# Out:
# taster_name
# Alexander Peartree    85.855422
# Anna Lee C. Iijima    88.415629
# Anne Krebiehl MW      90.562551
# Carrie Dykes          86.395683
# Christina Pickard     87.833333
# Fiona Adams           86.888889
# Jeff Jenssen          88.319756
# Jim Gordon            88.626287
# Joe Czerwinski        88.536235
# Kerin O’Keefe         88.867947
# Lauren Buzzeo         87.739510
# Matt Kettmann         90.008686
# Michael Schachner     86.907493
# Mike DeSimone         89.101167
# Paul Gregutt          89.082564
# Roger Voss            88.708003
# Sean P. Sullivan      88.755739
# Susan Kostrzewa       86.609217
# Virginie Boone        89.213379
# Name: points, dtype: float64

# %%
x.groupby("taster_name").points.min()
# Out:
# taster_name
# Alexander Peartree    80
# Anna Lee C. Iijima    80
# Anne Krebiehl MW      80
# Carrie Dykes          81
# Christina Pickard     82
# Fiona Adams           82
# Jeff Jenssen          82
# Jim Gordon            80
# Joe Czerwinski        80
# Kerin O’Keefe         80
# Lauren Buzzeo         81
# Matt Kettmann         81
# Michael Schachner     80
# Mike DeSimone         82
# Paul Gregutt          80
# Roger Voss            80
# Sean P. Sullivan      80
# Susan Kostrzewa       80
# Virginie Boone        80
# Name: points, dtype: int64

# %%
x.groupby("title").points.max()
# Out:
# title
# 1+1=3 2008 Rosé Cabernet Sauvignon (Penedès)                                             82
# 1+1=3 NV Brut Sparkling (Cava)                                                           87
# 1+1=3 NV Cygnus Brut Nature Reserva Made With Organic Grapes Sparkling (Cava)            89
# 1+1=3 NV Rosé Sparkling (Cava)                                                           86
# 10 Knots 2006 Beachcomber White (Paso Robles)                                            83
# 10 Knots 2006 Chardonnay (Santa Barbara County)                                          85
# 10 Knots 2009 Moonraker Grenache (Paso Robles)                                           81
# 10 Knots 2010 Viognier (Paso Robles)                                                     84
# 100 Percent Wine 2012 All Profits to Charity Red (California)                            89
# 100 Percent Wine 2014 All Profits to Charity Sauvignon Blanc (California)                84
# ...

# %%
#1. Cheapest wine in each point value category

x.groupby("title").points.min()
# Out:
# title
# 1+1=3 2008 Rosé Cabernet Sauvignon (Penedès)                                             82
# 1+1=3 NV Brut Sparkling (Cava)                                                           87
# 1+1=3 NV Cygnus Brut Nature Reserva Made With Organic Grapes Sparkling (Cava)            89
# 1+1=3 NV Rosé Sparkling (Cava)                                                           86
# 10 Knots 2006 Beachcomber White (Paso Robles)                                            83
# 10 Knots 2006 Chardonnay (Santa Barbara County)                                          85
# 10 Knots 2009 Moonraker Grenache (Paso Robles)                                           81
# 10 Knots 2010 Viognier (Paso Robles)                                                     84
# 100 Percent Wine 2012 All Profits to Charity Red (California)                            89
# 100 Percent Wine 2014 All Profits to Charity Sauvignon Blanc (California)                84
# ...

# %%
#2. Cheapest cost for each wine
x.groupby("title").price.min()
# Out:
# title
# 1+1=3 2008 Rosé Cabernet Sauvignon (Penedès)                                             18.0
# 1+1=3 NV Brut Sparkling (Cava)                                                           16.0
# 1+1=3 NV Cygnus Brut Nature Reserva Made With Organic Grapes Sparkling (Cava)            20.0
# 1+1=3 NV Rosé Sparkling (Cava)                                                           20.0
# 10 Knots 2006 Beachcomber White (Paso Robles)                                            21.0
# 10 Knots 2006 Chardonnay (Santa Barbara County)                                          21.0
# 10 Knots 2009 Moonraker Grenache (Paso Robles)                                           35.0
# 10 Knots 2010 Viognier (Paso Robles)                                                     22.0
# 100 Percent Wine 2012 All Profits to Charity Red (California)                            18.0
# 100 Percent Wine 2014 All Profits to Charity Sauvignon Blanc (California)                18.0
# ...

# %%
#3. Name of the first wine produced by each winery
x.groupby("winery").apply(lambda df : df.title.iloc[0])
# Out:
# winery
# 1+1=3                                      1+1=3 NV Rosé Sparkling (Cava)
# 10 Knots                             10 Knots 2010 Viognier (Paso Robles)
# 100 Percent Wine               100 Percent Wine 2015 Moscato (California)
# 1000 Stories            1000 Stories 2013 Bourbon Barrel Aged Zinfande...
# 1070 Green                   1070 Green 2011 Sauvignon Blanc (Rutherford)
# 10Span                             10Span 2013 Pinot Noir (Central Coast)
# 12 Linajes                    12 Linajes 2009 Reserva  (Ribera del Duero)
# 12C Wines               12C Wines 2012 Beckstoffer Vineyard  Georges I...
# 13 Celsius                  13 Celsius 2014 Sauvignon Blanc (Marlborough)
# 14 Hands                              14 Hands 2010 Riesling (Washington)
# 16X20                                16X20 2010 Chardonnay (Sonoma Coast)
# 1752 Signature Wines    1752 Signature Wines 2016 Marion Rosé (Côtes d...
# 1789 Wines                1789 Wines 2007 Pinot Noir (Chehalem Mountains)
# ...

# %%
#4. Minimum and maximum prices for each variety of wine
x.groupby("variety").price.agg([min,max])
# Out:
#                          min    max
# variety
# Abouriou                15.0   75.0
# Agiorgitiko             10.0   66.0
# Aglianico                6.0  180.0
# Aidani                  27.0   27.0
# Airen                    8.0   10.0
# Albana                  12.0   50.0
# Albanello               20.0   20.0
# Albariño                10.0   75.0
# Albarossa               40.0   40.0
# Aleatico                25.0   55.0
# Alfrocheiro             11.0   50.0
# Alicante                10.0   30.0
# Alicante Bouschet        7.0  150.0
# Aligoté                 13.0   36.0
# Alsace white blend      10.0   98.0
# Altesse                 15.0   19.0
# Alvarelhão              18.0   24.0
# Alvarinho                9.0   75.0
# Alvarinho-Chardonnay     9.0   15.0
# Ansonica                22.0   30.0
# Antão Vaz               11.0   30.0
# Apple                   25.0   33.0
# Aragonez                10.0   35.0
# Aragonês                14.0   70.0
# Argaman                 36.0   48.0
# ...

# %%
x.groupby(["country","province"]).apply(lambda df: df.loc[df.points.idxmax])
# Out:
#                                Unnamed: 0    country  \
# country   province
# Argentina Mendoza Province          82754  Argentina
#           Other                     78303  Argentina
# Armenia   Armenia                   66146    Armenia
# Australia Australia Other           37882  Australia
#           New South Wales           85337  Australia
#           South Australia           56953  Australia
#           Tasmania                  76216  Australia
#           Victoria                    345  Australia
#           Western Australia         87137  Australia
# Austria   Austria                   39456    Austria
#           Burgenland               109406    Austria
#           Carnuntum                102830    Austria
#           Eisenberg                119664    Austria
#           Kamptal                   47434    Austria
#           Kremstal                  54308    Austria
#           Leithaberg                27575    Austria
# ...

# %%
x.country.isnull()
# Out:
# 129971

# %%
x.country.notnull()
# Out:
# 0         True
# 1         True
# 2         True
# 3         True
# 4         True
# 5         True
# 6         True
# 7         True
# 8         True
# 9         True
# 10        True
# 11        True
# 12        True
# 13        True
# 14        True
# 15        True
# 16        True
# 17        True
# 18        True
# 19        True
# 20        True
# 21        True
# 22        True
# 23        True
# 24        True
# 25        True
# 26        True
# 27        True
# 28        True
# 29        True
#           ...
# 129941    True
# 129942    True
# 129943    True
# 129944    True
# 129945    True
# 129946    True
# 129947    True
# 129948    True
# 129949    True
# 129950    True
# 129951    True
# 129952    True
# 129953    True
# 129954    True
# 129955    True
# 129956    True
# 129957    True
# 129958    True
# 129959    True
# 129960    True
# 129961    True
# 129962    True
# 129963    True
# 129964    True
# 129965    True
# 129966    True
# 129967    True
# ...

# %%
x.region_2.fillna("Unknown")
# Out:
# 0                   Unknown
# 1                   Unknown
# 2         Willamette Valley
# 3                   Unknown
# 4         Willamette Valley
# 5                   Unknown
# 6                   Unknown
# 7                   Unknown
# 8                   Unknown
# 9                   Unknown
# 10                     Napa
# 11                  Unknown
# 12                   Sonoma
# 13                  Unknown
# 14            Central Coast
# 15                  Unknown
# 16                  Unknown
# 17                  Unknown
# 18                  Unknown
# 19                  Unknown
# 20                  Unknown
# 21             Oregon Other
# 22                  Unknown
# 23            Central Coast
# 24                  Unknown
# 25                   Sonoma
# 26                  Unknown
# 27                  Unknown
# 28                  Unknown
# 29           Central Valley
#                 ...
# 129941              Unknown
# 129942               Sonoma
# ...

# %%
x.taster_twitter_handle.replace("@kerinokeefe","@kerino")
# Out:
# 0                @kerino
# 1             @vossroger
# 2            @paulgwine
# 3                    NaN
# 4            @paulgwine
# 5            @wineschach
# 6                @kerino
# 7             @vossroger
# 8                    NaN
# 9             @vossroger
# 10               @vboone
# 11            @vossroger
# 12               @vboone
# 13               @kerino
# 14         @mattkettmann
# 15                   NaN
# 16           @wineschach
# 17           @wineschach
# 18           @wineschach
# 19                   NaN
# 20                   NaN
# 21           @paulgwine
# 22               @kerino
# 23         @mattkettmann
# 24               @kerino
# 25               @vboone
# 26               @kerino
# 27               @kerino
# 28               @kerino
# 29               @vboone
#                ...
# 129941           @vboone
# 129942           @vboone
# 129943           @kerino
# 129944    @worldwineguys
# 129945     @mattkettmann
# 129946               NaN
# ...
